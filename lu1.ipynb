# %%
a=int(input("enter the first number"))
b=int(input("enter the second number"))
sum=a+b
print("sum is ",sum)

sub=a-b
print("the subtrated number ",sub)

multi=a*b
print ("the multiplied number",multi)

div=a/b
print("the result ",div)
# Out:
# enter the first number25
# enter the second number5
# sum is  30
# the subtrated number  20
# the multiplied number 125
# the result  5.0
