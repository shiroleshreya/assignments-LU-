# %%
n=int(input("enter number of participants"))
participants=[input() for i in range(n)]
print(participants)
import random
m=random.randint(0,n-1)
participants[m]
# Out:
# enter number of participants4
# Shreya
# Chirag
# Chinmay
# Rashmi
# ['Shreya', 'Chirag', 'Chinmay', 'Rashmi']
# 'Shreya'
